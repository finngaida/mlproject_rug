# %%
import pandas as pd

# %%
colnames= ['IMG_ABS_PATH', 'class_name', 'x1', 'y1', 'x2', 'y2']
odf = pd.read_csv('../MIO-TCD-Localization/gt_train.csv',names=colnames)

# %%
odf
# Out:
#         IMG_ABS_PATH             class_name   x1   y1   x2   y2
# 0                  0           pickup_truck  213   34  255   50
# 1                  0                    car  194   78  273  122
# 2                  0                    car  155   27  183   35
# 3                  0      articulated_truck   43   25  109   55
# 4                  0                    car  106   32  124   45
# 5                  1                    bus  205  155  568  314
# 6                  1                    bus  285  123  477  168
# 7                  1                    car  544  162  617  193
# 8                  1                    car  329  152  371  163
# 9                  1                    car  447  161  497  183
# 10                 1                    car  662  199  715  236
# 11                 2      motorized_vehicle  334  362  603  479
# 12                 3                    car  480   99  511  120
# 13                 3                    car  257  199  369  280
# ...

# %%
t = odf.loc[odf['class_name'].isin(['bicycle','pedestrian'])]

# %%
t
# Out:
#         IMG_ABS_PATH  class_name   x1   y1   x2   y2
# 145               47  pedestrian  266   46  283   72
# 227               73     bicycle   84  376  237  470
# 362              118  pedestrian  528   77  542  121
# 363              118     bicycle  251  124  288  187
# 364              118  pedestrian  508   79  521  120
# 365              118  pedestrian  544  185  580  305
# 366              118     bicycle  362  137  408  242
# 378              124  pedestrian   10  292   40  351
# 473              144     bicycle  462   86  483  122
# 474              144     bicycle  439  106  459  154
# 484              146  pedestrian    6  391   95  458
# 486              146  pedestrian   27  349  111  431
# 519              159  pedestrian  255   21  272   52
# 593              184     bicycle  412    0  478   47
# 594              184     bicycle  658  179  717  241
# 595              184     bicycle  537   65  604  148
# 664              207  pedestrian  184  201  195  222
# ...
